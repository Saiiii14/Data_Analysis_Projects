# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\Sai Sailesh\Downloads\top-5000-youtube-channels.csv")
data
# Out:
#          Rank Grade                Channel name Video Uploads Subscribers  \
# 0         1st  A++                       Zee TV         82757    18752951
# 1         2nd  A++                     T-Series         12661    61196302
# 2         3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3         4th  A++                    SET India         27323    31180559
# 4         5th  A++                          WWE         36756    32852346
# ...       ...   ...                         ...           ...         ...
# 4995  4,996th   B+               Uras Benlioğlu           706     2072942
# 4996  4,997th   B+            HI-TECH MUSIC LTD           797     1055091
# 4997  4,998th   B+                  Mastersaint           110     3265735
# 4998  4,999th   B+               Bruce McIntosh          3475       32990
# 4999  5,000th   B+                    SehatAQUA           254       21172
#
#       Video views
# 0     20869786591
# 1     47548839843
# 2      9793305082
# ...

# %%
data.head(-5)
# Out:
#          Rank Grade                      Channel name Video Uploads  \
# 0         1st  A++                             Zee TV         82757
# 1         2nd  A++                           T-Series         12661
# 2         3rd  A++         Cocomelon - Nursery Rhymes           373
# 3         4th  A++                          SET India         27323
# 4         5th  A++                                WWE         36756
# ...       ...   ...                               ...           ...
# 4990  4,991st   B+      Ho Ngoc Ha's Official Channel           208
# 4991  4,992nd   B+               Toys to Learn Colors            11
# 4992  4,993rd   B+                              КАZКА            25
# 4993  4,994th   B+   United CUBE (CUBE Entertainment…          1055
# 4994  4,995th   B+                      Wings Marathi          1735
#
#      Subscribers  Video views
# 0       18752951  20869786591
# 1       61196302  47548839843
# 2       19238251   9793305082
# ...

# %%
data.tail(-5)
# Out:
#          Rank Grade           Channel name Video Uploads Subscribers  \
# 5         6th  A++              Movieclips         30243    17149705
# 6         7th  A++              netd müzik          8500    11373567
# 7         8th  A++   ABS-CBN Entertainment        100147    12149206
# 8         9th  A++         Ryan ToysReview          1140    16082927
# 9        10th  A++             Zee Marathi         74607     2841811
# ...       ...   ...                    ...           ...         ...
# 4995  4,996th   B+          Uras Benlioğlu           706     2072942
# 4996  4,997th   B+       HI-TECH MUSIC LTD           797     1055091
# 4997  4,998th   B+             Mastersaint           110     3265735
# 4998  4,999th   B+          Bruce McIntosh          3475       32990
# 4999  5,000th   B+               SehatAQUA           254       21172
#
#       Video views
# 5     16618094724
# 6     23898730764
# 7     17202609850
# 8     24518098041
# 9      2591830307
# ...           ...
# ...

# %%
data.shape
# Out:
# (5000, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           5000 non-null   object
#  1   Grade          5000 non-null   object
#  2   Channel name   5000 non-null   object
#  3   Video Uploads  5000 non-null   object
#  4   Subscribers    5000 non-null   object
#  5   Video views    5000 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %%
data.describe(include='all')
# Out:
#         Rank Grade Channel name Video Uploads Subscribers        Video views
# count   5000  5000         5000          5000        5000        5000.000000
# unique  5000     6         4993          2286        4612                NaN
# top      1st   B+    Thơ Nguyễn            26         --                 NaN
# freq       1  2956            2            17         387                NaN
# mean     NaN   NaN          NaN           NaN         NaN  1071449400.150000
# std      NaN   NaN          NaN           NaN         NaN  2003843972.123988
# min      NaN   NaN          NaN           NaN         NaN          75.000000
# 25%      NaN   NaN          NaN           NaN         NaN   186232945.750000
# 50%      NaN   NaN          NaN           NaN         NaN   482054780.000000
# 75%      NaN   NaN          NaN           NaN         NaN  1124367826.750000
# max      NaN   NaN          NaN           NaN         NaN 47548839843.000000

# %% [markdown]
# # Replace '--' to nan

# %%
data.head(20)
# Out:
#     Rank Grade                Channel name Video Uploads Subscribers  \
# 0    1st  A++                       Zee TV         82757    18752951
# 1    2nd  A++                     T-Series         12661    61196302
# 2    3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3    4th  A++                    SET India         27323    31180559
# 4    5th  A++                          WWE         36756    32852346
# 5    6th  A++                   Movieclips         30243    17149705
# 6    7th  A++                   netd müzik          8500    11373567
# 7    8th  A++        ABS-CBN Entertainment        100147    12149206
# 8    9th  A++              Ryan ToysReview          1140    16082927
# 9   10th  A++                  Zee Marathi         74607     2841811
# 10  11th   A+              5-Minute Crafts          2085    33492951
# 11  12th   A+              Canal KondZilla           822    39409726
# 12  13th   A+             Like Nastya Vlog           150     7662886
# ...

# %%
data=data.replace('--',np.nan,regex=True)

# %%
data
# Out:
#          Rank Grade                Channel name Video Uploads Subscribers  \
# 0         1st  A++                       Zee TV         82757    18752951
# 1         2nd  A++                     T-Series         12661    61196302
# 2         3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3         4th  A++                    SET India         27323    31180559
# 4         5th  A++                          WWE         36756    32852346
# ...       ...   ...                         ...           ...         ...
# 4995  4,996th   B+               Uras Benlioğlu           706     2072942
# 4996  4,997th   B+            HI-TECH MUSIC LTD           797     1055091
# 4997  4,998th   B+                  Mastersaint           110     3265735
# 4998  4,999th   B+               Bruce McIntosh          3475       32990
# 4999  5,000th   B+                    SehatAQUA           254       21172
#
#       Video views
# 0     20869786591
# 1     47548839843
# 2      9793305082
# ...

# %%
data.isnull().sum()
# Out:
# Rank               0
# Grade              0
# Channel name       0
# Video Uploads      6
# Subscribers      387
# Video views        0
# dtype: int64

# %%
per_missing=data.isnull().sum()*100/len(data)

# %%
per_missing
# Out:
# Rank            0.000000
# Grade           0.000000
# Channel name    0.000000
# Video Uploads   0.120000
# Subscribers     7.740000
# Video views     0.000000
# dtype: float64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.dropna(axis=0,inplace=True)

# %%
data.isnull().sum()
# Out:
# Rank             0
# Grade            0
# Channel name     0
# Video Uploads    0
# Subscribers      0
# Video views      0
# dtype: int64

# %%
data
# Out:
#          Rank Grade                Channel name Video Uploads Subscribers  \
# 0         1st  A++                       Zee TV         82757    18752951
# 1         2nd  A++                     T-Series         12661    61196302
# 2         3rd  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3         4th  A++                    SET India         27323    31180559
# 4         5th  A++                          WWE         36756    32852346
# ...       ...   ...                         ...           ...         ...
# 4995  4,996th   B+               Uras Benlioğlu           706     2072942
# 4996  4,997th   B+            HI-TECH MUSIC LTD           797     1055091
# 4997  4,998th   B+                  Mastersaint           110     3265735
# 4998  4,999th   B+               Bruce McIntosh          3475       32990
# 4999  5,000th   B+                    SehatAQUA           254       21172
#
#       Video views
# 0     20869786591
# 1     47548839843
# 2      9793305082
# ...

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # data cleaning [rank column]

# %%
data['Rank']
# Out:
# 0           1st
# 1           2nd
# 2           3rd
# 3           4th
# 4           5th
#          ...
# 4995    4,996th
# 4996    4,997th
# 4997    4,998th
# 4998    4,999th
# 4999    5,000th
# Name: Rank, Length: 4610, dtype: object

# %%
data.dtypes
# Out:
# Rank             object
# Grade            object
# Channel name     object
# Video Uploads    object
# Subscribers      object
# Video views       int64
# dtype: object

# %%
data['Rank']=data['Rank'].str[0:-2]

# %%
data['Rank']=data['Rank'].str.replace(',','')

# %%
data
# Out:
#       Rank Grade                Channel name Video Uploads Subscribers  \
# 0        1  A++                       Zee TV         82757    18752951
# 1        2  A++                     T-Series         12661    61196302
# 2        3  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3        4  A++                    SET India         27323    31180559
# 4        5  A++                          WWE         36756    32852346
# ...    ...   ...                         ...           ...         ...
# 4995  4996   B+               Uras Benlioğlu           706     2072942
# 4996  4997   B+            HI-TECH MUSIC LTD           797     1055091
# 4997  4998   B+                  Mastersaint           110     3265735
# 4998  4999   B+               Bruce McIntosh          3475       32990
# 4999  5000   B+                    SehatAQUA           254       21172
#
#       Video views
# 0     20869786591
# 1     47548839843
# 2      9793305082
# 3     22675948293
# ...

# %%
data.tail()
# Out:
#       Rank Grade       Channel name Video Uploads Subscribers  Video views
# 4995  4996   B+      Uras Benlioğlu           706     2072942    441202795
# 4996  4997   B+   HI-TECH MUSIC LTD           797     1055091    377331722
# 4997  4998   B+         Mastersaint           110     3265735    311758426
# 4998  4999   B+      Bruce McIntosh          3475       32990     14563764
# 4999  5000   B+           SehatAQUA           254       21172     73312511

# %%
data['Rank']=data['Rank'].str.replace(',','').astype('int')

# %%
data.dtypes
# Out:
# Rank              int32
# Grade            object
# Channel name     object
# Video Uploads    object
# Subscribers      object
# Video views       int64
# dtype: object

# %% [markdown]
# # data cleaning[ video uploads &  subscribers ]

# %%
data.head()
# Out:
#    Rank Grade                Channel name Video Uploads Subscribers  \
# 0     1  A++                       Zee TV         82757    18752951
# 1     2  A++                     T-Series         12661    61196302
# 2     3  A++   Cocomelon - Nursery Rhymes           373    19238251
# 3     4  A++                    SET India         27323    31180559
# 4     5  A++                          WWE         36756    32852346
#
#    Video views
# 0  20869786591
# 1  47548839843
# 2   9793305082
# 3  22675948293
# 4  26273668433

# %%
data['Video Uploads']=data['Video Uploads'].astype('int')

# %%
data['Subscribers	']=data['Subscribers'].astype('int')

# %%
data.dtypes
# Out:
# Rank              int32
# Grade            object
# Channel name     object
# Video Uploads     int32
# Subscribers      object
# Video views       int64
# Subscribers\t     int32
# dtype: object

# %% [markdown]
# # data cleaning [grade column]

# %%
data.head()
# Out:
#    Rank Grade                Channel name  Video Uploads Subscribers  \
# 0     1  A++                       Zee TV          82757    18752951
# 1     2  A++                     T-Series          12661    61196302
# 2     3  A++   Cocomelon - Nursery Rhymes            373    19238251
# 3     4  A++                    SET India          27323    31180559
# 4     5  A++                          WWE          36756    32852346
#
#    Video views  Subscribers\t
# 0  20869786591       18752951
# 1  47548839843       61196302
# 2   9793305082       19238251
# 3  22675948293       31180559
# 4  26273668433       32852346

# %%
data['Grade'].unique()
# Out:
# array(['A++ ', 'A+ ', 'A ', 'A- ', 'B+ '], dtype=object)

# %%
data['Grade']=data['Grade'].map({'A++ ':5,'A+ ':4,'A ':3,'A- ':2,'B+ ':1})

# %%
data
# Out:
#       Rank  Grade                Channel name  Video Uploads Subscribers  \
# 0        1      5                      Zee TV          82757    18752951
# 1        2      5                    T-Series          12661    61196302
# 2        3      5  Cocomelon - Nursery Rhymes            373    19238251
# 3        4      5                   SET India          27323    31180559
# 4        5      5                         WWE          36756    32852346
# ...    ...    ...                         ...            ...         ...
# 4995  4996      1              Uras Benlioğlu            706     2072942
# 4996  4997      1           HI-TECH MUSIC LTD            797     1055091
# 4997  4998      1                 Mastersaint            110     3265735
# 4998  4999      1              Bruce McIntosh           3475       32990
# 4999  5000      1                   SehatAQUA            254       21172
#
#       Video views  Subscribers\t
# 0     20869786591       18752951
# ...

# %% [markdown]
# # Find the avg views for each channel

# %%
data.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views', 'Subscribers\t'],
#       dtype='object')

# %%
data['Video views'].mean()
# Out:
# 1138403081.178959

# %%
data.head()
# Out:
#    Rank  Grade                Channel name  Video Uploads Subscribers  \
# 0     1      5                      Zee TV          82757    18752951
# 1     2      5                    T-Series          12661    61196302
# 2     3      5  Cocomelon - Nursery Rhymes            373    19238251
# 3     4      5                   SET India          27323    31180559
# 4     5      5                         WWE          36756    32852346
#
#    Video views  Subscribers\t
# 0  20869786591       18752951
# 1  47548839843       61196302
# 2   9793305082       19238251
# 3  22675948293       31180559
# 4  26273668433       32852346

# %%
data['Avg_views']=data['Video views']/data['Video Uploads']

# %%
pd.options.display.float_format = '{:.6f}'.format

# %%
data.head()
# Out:
#    Rank  Grade                Channel name  Video Uploads Subscribers  \
# 0     1      5                      Zee TV          82757    18752951
# 1     2      5                    T-Series          12661    61196302
# 2     3      5  Cocomelon - Nursery Rhymes            373    19238251
# 3     4      5                   SET India          27323    31180559
# 4     5      5                         WWE          36756    32852346
#
#    Video views  Subscribers\t       Avg_views
# 0  20869786591       18752951   252181.526529
# 1  47548839843       61196302  3755535.885238
# 2   9793305082       19238251 26255509.603217
# 3  22675948293       31180559   829921.615233
# 4  26273668433       32852346   714813.049108

# %% [markdown]
# # Find out the top 5 channels with max number of video uploads

# %%
data.columns
# Out:
# Index(['Rank', 'Grade', 'Channel name', 'Video Uploads', 'Subscribers',
#        'Video views', 'Subscribers\t', 'Avg_views'],
#       dtype='object')

# %%
data.sort_values(by='Video Uploads',ascending=False)['Channel name'].head()
# Out:
# 3453    AP Archive
# 1149      YTN NEWS
# 2223     SBS Drama
# 323       GMA News
# 2956           MLB
# Name: Channel name, dtype: object

# %% [markdown]
# # Find Correlation matrix

# %%
 data=data.select_dtypes(include='number')

# %%
data.corr()
# Out:
#                    Rank     Grade  Video Uploads  Video views  Subscribers\t  \
# Rank           1.000000 -0.865083      -0.073180    -0.402873      -0.383329
# Grade         -0.865083  1.000000       0.088773     0.477423       0.429213
# Video Uploads -0.073180  0.088773       1.000000     0.087830       0.011362
# Video views   -0.402873  0.477423       0.087830     1.000000       0.791241
# Subscribers\t -0.383329  0.429213       0.011362     0.791241       1.000000
# Avg_views     -0.153670  0.155231      -0.064408     0.294422       0.289386
#
#                Avg_views
# Rank           -0.153670
# Grade           0.155231
# Video Uploads  -0.064408
# Video views     0.294422
# Subscribers\t   0.289386
# Avg_views       1.000000

# %% [markdown]
# # Which grade has a max num of video uploads

# %%
data
# Out:
#       Rank  Grade  Video Uploads  Video views  Subscribers\t       Avg_views
# 0        1      5          82757  20869786591       18752951   252181.526529
# 1        2      5          12661  47548839843       61196302  3755535.885238
# 2        3      5            373   9793305082       19238251 26255509.603217
# 3        4      5          27323  22675948293       31180559   829921.615233
# 4        5      5          36756  26273668433       32852346   714813.049108
# ...    ...    ...            ...          ...            ...             ...
# 4995  4996      1            706    441202795        2072942   624933.137394
# 4996  4997      1            797    377331722        1055091   473440.052698
# 4997  4998      1            110    311758426        3265735  2834167.509091
# 4998  4999      1           3475     14563764          32990     4191.011223
# 4999  5000      1            254     73312511          21172   288631.933071
#
# [4610 rows x 6 columns]

# %%
data.groupby('Grade')['Video Uploads'].mean()
# Out:
# Grade
# 1    3136.157237
# 2    4382.582359
# 3    5709.855072
# 4   16960.300000
# 5   37450.700000
# Name: Video Uploads, dtype: float64

# %%
sns.barplot(x='Grade',y='Video Uploads',data=data)
# Out:
# <Axes: xlabel='Grade', ylabel='Video Uploads'>

# %% [markdown]
# # which grade has highest avg views

# %%
sns.barplot(x='Grade',y='Avg_views',data=data)
# Out:
# <Axes: xlabel='Grade', ylabel='Avg_views'>
